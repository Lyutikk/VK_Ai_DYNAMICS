# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.metrics import mean_squared_error

# Для визуализации графиков CatBoost надо установить ipywidgets
#!pip install ipywidgets
# jupyter nbextension enable --py widgetsnbextension
import ipywidgets

pd.options.mode.chained_assignment = None

# %%
PATH = "datasets/train_dataset_VK/"
submission_filename = "submission.csv"

# %% [markdown]
# ## Загрузка данных

# %%
# Обучающая выборка разбита на файлы
datset_filenames = ["rich_test_1M_1.csv", "rich_test_1M_2.csv", "rich_test_1M_3.csv", "rich_test_1M_4.csv", "rich_test_1M_5.csv"]
datset_df = pd.DataFrame()
for filename in datset_filenames:
    partfile_df = pd.read_csv(PATH + filename)
    datset_df = pd.concat([datset_df, partfile_df], axis=0)
datset_df.shape
# Out:
# (4315675, 21)

# %%
datset_df
# Out:
#               ego_id    u    v      t            x1       x2   x3  is_t_exist  \
# 0        42949673176    0  244  169.2  6.706259e-05  0.00000  0.0           1
# 1        42949673176    0   98  225.9           NaN  0.00000  0.0           1
# 2        42949673176   97   98  221.2           NaN  0.00000  0.0           1
# 3        42949673176    9   98    0.0  4.284449e-02  0.00000  0.0           0
# 4        42949673176   33   98  148.3  1.011391e+00  0.00000  0.0           1
# ...              ...  ...  ...    ...           ...      ...  ...         ...
# 870616  266287972376  249  250  286.8  7.138040e-03  0.00000  0.0           1
# 870617  266287972376  274  269  205.7  1.794510e+00  1.94591  1.0           1
# 870618  266287972376  277  269  156.2  8.951802e-01  0.00000  1.0           1
# 870619  266287972376  242  243  303.5           NaN  0.00000  1.0           1
# 870620  266287972376  155  156  417.7  3.812440e-08  0.00000  0.0           1
#
#         friendship  age_x  ...  sex_2_x  city_freq_x  university_freq_x  \
# 0         0.181489     35  ...        1           13                154
# 1         0.228191     35  ...        1           13                154
# 2         0.569724     32  ...        1           98                154
# 3         0.477254     29  ...        1           98                  7
# 4         0.637653     32  ...        0           98                154
# ...            ...    ...  ...      ...          ...                ...
# 870616    0.022189     35  ...        0           14                 89
# 870617    1.094208     19  ...        1          127                 89
# 870618    1.076704     20  ...        1          127                 89
# 870619    0.008248     35  ...        1          127                 89
# 870620    0.000003     35  ...        1          127                 89
#
#         school_freq_x  age_y  sex_1_y  sex_2_y  city_freq_y  \
# 0                 101    121        1        0           13
# 1                 101     30        0        1           98
# 2                   5     30        0        1           98
# 3                 101     30        0        1           98
# 4                  16     30        0        1           98
# ...               ...    ...      ...      ...          ...
# 870616             93     35        1        0            1
# 870617              1     26        0        1          127
# 870618              1     26        0        1          127
# 870619              1     34        1        0          127
# 870620             93     36        0        1            4
#
#         university_freq_y  school_freq_y
# 0                     154            101
# 1                     154             16
# 2                     154             16
# 3                     154             16
# 4                     154             16
# ...                   ...            ...
# 870616                  1             93
# 870617                 89              1
# 870618                 89              1
# 870619                 10              1
# 870620                 89             93
#
# [4315675 rows x 21 columns]

# %% [markdown]
# ### Готовим данные для модели

# %%
train_df = datset_df[datset_df["x1"].notna()]
test_df = datset_df[datset_df["x1"].isna()]
test_df.shape, train_df.shape
# Out:
# ((863413, 21), (3452262, 21))

# %%
# train_df.columns
data_columns = ['u', 'v', 't', 'x2', 'x3', 'is_t_exist', 'friendship', 'age_x', 'sex_1_x', 'sex_2_x', 'city_freq_x', 'university_freq_x', 'school_freq_x', 'age_y', 'sex_1_y', 'sex_2_y', 'city_freq_y', 'university_freq_y', 'school_freq_y']
target_column = "x1"

x_train_df = train_df[data_columns]
y_train_df = train_df[target_column]
y_test = test_df[data_columns]

x_train_df.shape, y_train_df.shape
# Out:
# ((3452262, 19), (3452262,))

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_df, y_train_df, test_size=0.2, random_state=53, shuffle=True)
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((2761809, 19), (690453, 19), (2761809,), (690453,))

# %% [markdown]
# ### Обучаем модель

# %%
from catboost import CatBoostRegressor, Pool
from catboost import cv
cat = CatBoostRegressor()

cat.fit(x_train, y_train, eval_set=(x_val, y_val), verbose=False, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
# Производим кроссвалидацию (минимальная)
params = {"iterations": 100,
          "depth": 2,
          "loss_function": "RMSE",
          "verbose": False}
cv_dataset = Pool(data=x_train,
                  label=y_train)
scores = cv(cv_dataset,
            params, 
            fold_count=2, 
            plot="True")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/2]
#
# bestTest = 0.9223846089
# bestIteration = 99
#
# Training on fold [1/2]
#
# bestTest = 0.9230336149
# bestIteration = 99

# %%
# Формируем предсказания на тестовых данных
test_df["predict"] = cat.predict(y_test)
test_df
# Out:
#               ego_id    u    v      t  x1   x2   x3  is_t_exist  friendship  \
# 1        42949673176    0   98  225.9 NaN  0.0  0.0           1    0.228191
# 2        42949673176   97   98  221.2 NaN  0.0  0.0           1    0.569724
# 5        42949673176  121   98  233.5 NaN  0.0  0.0           1    0.538926
# 21       42949673176   35  298  299.6 NaN  0.0  0.0           1    0.316065
# 22       42949673176   94  298  253.9 NaN  0.0  0.0           1    0.165649
# ...              ...  ...  ...    ...  ..  ...  ...         ...         ...
# 870595  266287972376  183  214  392.9 NaN  0.0  0.0           1    0.618966
# 870598  266287972376   85   94   12.8 NaN  0.0  0.0           1    0.202401
# 870608  266287972376  220  219  260.3 NaN  0.0  0.0           1    0.059710
# 870611  266287972376  144  220   54.4 NaN  0.0  0.0           1    0.027634
# 870619  266287972376  242  243  303.5 NaN  0.0  1.0           1    0.008248
#
#         age_x  ...  city_freq_x  university_freq_x  school_freq_x  age_y  \
# 1          35  ...           13                154            101     30
# 2          32  ...           98                154              5     30
# 5          25  ...            9                  1             16     30
# 21         30  ...           98                154             16     32
# 22         28  ...           98                154              4     32
# ...       ...  ...          ...                ...            ...    ...
# 870595     35  ...           22                 89             93     38
# 870598    103  ...          127                 10              1     41
# 870608     36  ...           20                 89             93     34
# 870611     35  ...           20                 89              2     36
# 870619     35  ...          127                 89              1     34
#
#         sex_1_y  sex_2_y  city_freq_y  university_freq_y  school_freq_y  \
# 1             0        1           98                154             16
# 2             0        1           98                154             16
# 5             0        1           98                154             16
# 21            0        1           98                154            101
# 22            0        1           98                154            101
# ...         ...      ...          ...                ...            ...
# 870595        0        1           14                 19              3
# 870598        0        1          127                 10              3
# 870608        1        0           22                  3              1
# 870611        0        1           20                 89             93
# 870619        1        0          127                 10              1
#
#          predict
# 1       0.169366
# 2       0.374552
# 5       0.310310
# 21      0.215561
# 22      0.162873
# ...          ...
# 870595  0.437776
# 870598  0.231767
# 870608  0.068618
# 870611  0.050701
# 870619  0.098805
#
# [863413 rows x 22 columns]

# %% [markdown]
# ### Обновляем знания в submission.csv

# %%
# Скачиваем действующий сабмит
submission = pd.read_csv(PATH + submission_filename)
submission.shape
# Out:
# (810976, 4)

# %%
# Объединяем с предсказаниями из теста
result_submission = submission.merge(test_df[["ego_id", "u", "v", "predict"]], on=["ego_id", "u", "v"], how='left')
result_submission.shape
# Out:
# (810976, 5)

# %%
# Обновляем сабмит тмеми предсказаниями которые получены от модели
result_submission["x1"] = result_submission.apply(lambda x: x["x1"] if pd.isna(x["predict"]) else x["predict"], axis=1)
result_submission = result_submission[["ego_id", "u", "v", "x1"]]

# %%
# Сохраняем итоговый сабмит
result_submission.to_csv(PATH + "result_submission.csv", index=False)
